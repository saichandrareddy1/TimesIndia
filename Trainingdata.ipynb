# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("./Training Data.csv")

# %%
click = pd.read_csv("./click_log.csv")
# Out:
# C:\Users\lenovo\anaconda3\envs\Assign\lib\site-packages\IPython\core\interactiveshell.py:3166: DtypeWarning: Columns (22,24,25,26,29,30,31,32,33,34,46,47,48,49,50,51,52,53,54) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
click.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244864 entries, 0 to 244863
# Data columns (total 55 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Unnamed: 0                 244864 non-null  int64
#  1   imprId                     244864 non-null  object
#  2   clmbUserId                 244864 non-null  object
#  3   adSltDimId                 244864 non-null  int64
#  4   auds                       181829 non-null  object
#  5   allAuds                    231529 non-null  object
#  6   itemid                     244864 non-null  int64
#  7   algo                       244864 non-null  int64
#  8   advClientId                244864 non-null  int64
#  9   pubClientId                244864 non-null  int64
#  10  itmClmbLId                 244864 non-null  int64
#  11  tmpltId                    222565 non-null  float64
#  12  refUrl                     198414 non-null  object
# ...

# %%
data.head()
# Out:
#    clientid_cr                               clmbuserid_cr  conversiontime_cr  \
# 0        75694  31629cd0-0b34-460f-aa61-80c3234e1225-1sjfw       1.620000e+12
# 1        75694  4c98f114-c34c-48f4-84d6-50fc8e9b6d65-10wgg       1.620000e+12
# 2        75694  cd92087a-54b0-4911-bc3d-1144a3c2babd-1sjlg       1.620000e+12
# 3        75694  f79f3de7-5edb-4319-9549-117f47996066-10wrk       1.620000e+12
# 4        30431  01fd1a8a-c3f8-4b57-94ff-66318d0f63c7-1sjts       1.620000e+12
#
#                                     imprid_cr  adslotdimid_cr  algo_cr  \
# 0  01649076-c77f-4d70-afc8-213535427147-1sjd4          321300     38.0
# 1  f84d83b9-b757-4f97-9813-34f8dcc57cc5-1sjfw          129239     38.0
# 2  061edef6-3d9d-408b-884a-ad840e6930ce-10o78          321554     21.0
# 3  0a937239-9091-4bb7-b26b-37d4bb29e50b-10oa0          321300     38.0
# 4  0d46d0d4-8fc6-4d95-aaa1-406354a8400c-1sjo8          355768     21.0
#
#       audiences_cr  clickbid_cr  geodimid_cr            ip_cr  ...  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 965 entries, 0 to 964
# Data columns (total 56 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   clientid_cr                    965 non-null    int64
#  1   clmbuserid_cr                  965 non-null    object
#  2   conversiontime_cr              965 non-null    float64
#  3   imprid_cr                      965 non-null    object
#  4   adslotdimid_cr                 965 non-null    int64
#  5   algo_cr                        945 non-null    float64
#  6   audiences_cr                   766 non-null    object
#  7   clickbid_cr                    669 non-null    float64
#  8   geodimid_cr                    965 non-null    int64
#  9   ip_cr                          945 non-null    object
#  10  itemcolumbiaid_cr              965 non-null    int64
#  11  itemid_cr                      965 non-null    int64
# ...

# %%
nullper = list(data.isna().sum() / len(data) * 100)

# %%
data_col = list(data.columns)
for i in range(len(nullper)):
    if nullper[i] > 40:
        data.drop([data_col[i]], axis=1, inplace=True)
    else:
        pass

# %%
data.isna().sum() / len(data) * 100
# Out:
# clientid_cr                       0.000000
# clmbuserid_cr                     0.000000
# conversiontime_cr                 0.000000
# imprid_cr                         0.000000
# adslotdimid_cr                    0.000000
# algo_cr                           2.072539
# audiences_cr                     20.621762
# clickbid_cr                      30.673575
# geodimid_cr                       0.000000
# ip_cr                             2.072539
# itemcolumbiaid_cr                 0.000000
# itemid_cr                         0.000000
# position_cr                       2.072539
# pubclientid_cr                    0.000000
# refurl_cr                        12.953368
# siteId_cr                         0.000000
# templateid_cr                    11.088083
# goalid_cr                         0.000000
# time_cr                           0.000000
# adLogType_cr                      0.000000
# v_cr                              0.103627
# allAudiences_cr                   4.870466
# ...

# %%
data_colums = data.columns

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
imp_mean.fit(data)
data = imp_mean.transform(data)

# %%
new_data = pd.DataFrame(data=data,columns=data_colums)

# %%
from collections import Counter


Counter(new_data['conversion_fraud'])
# Out:
# Counter({True: 131, False: 834})

# %%
# !pip install imblearn

# %%
new_data_main = new_data.drop(['clientid_cr', 'clmbuserid_cr', 'imprid_cr',
                              'audiences_cr', 'ip_cr', 'refurl_cr', 'connTypeDimId_cr', 'allAudiences_cr'], axis=1)

# %%
new_data_main
# Out:
#     conversiontime_cr adslotdimid_cr algo_cr clickbid_cr geodimid_cr  \
# 0     1620000000000.0         321300    38.0    2.869316         144
# 1     1620000000000.0         129239    38.0        2.79         144
# 2     1620000000000.0         321554    21.0        2.79         144
# 3     1620000000000.0         321300    38.0        2.79         144
# 4     1620000000000.0         355768    21.0        2.79         144
# ..                ...            ...     ...         ...         ...
# 960   1620000000000.0         321114    18.0         2.0         144
# 961   1620000000000.0         334758     6.0        2.79         144
# 962   1620000000000.0         348089     1.0        10.0         144
# 963   1620000000000.0         356952    21.0        2.79         144
# 964   1620000000000.0         356952    38.0        2.79         144
#
#     itemcolumbiaid_cr itemid_cr position_cr pubclientid_cr siteId_cr  ...  \
# ...

# %%
# Data Adding

# %%
cols = list(new_data_main.columns)
for i in range(len(cols)-1):
    print(cols[i])
    try:
        new_data_main[cols[i]] = new_data_main[cols[i]].astype("float")
    except:
        pass
# Out:
# conversiontime_cr
# adslotdimid_cr
# algo_cr
# clickbid_cr
# geodimid_cr
# itemcolumbiaid_cr
# itemid_cr
# position_cr
# pubclientid_cr
# siteId_cr
# templateid_cr
# goalid_cr
# time_cr
# adLogType_cr
# v_cr
# pricingtype_cr
# osId_cr
# browserId_cr
# cityId_cr
# stateId_cr
# modelDimId_cr
# lookUpFrom_cr
# ispDimId_cr
# countryDimId_cr
# goalTypeId_cr
# conversionDurationInMillis_cr
# impressionTimeInMillis_cr
# clickTimeInMillis_cr
# osVerDimId_cr
# uuidSource_cr
# geoGrpDimId_cr
# stateGrpDimId_cr
# cityGrpDimId_cr

# %%
new_data_main.dtypes
# Out:
# conversiontime_cr                float64
# adslotdimid_cr                   float64
# algo_cr                          float64
# clickbid_cr                      float64
# geodimid_cr                      float64
# itemcolumbiaid_cr                float64
# itemid_cr                        float64
# position_cr                      float64
# pubclientid_cr                   float64
# siteId_cr                        float64
# templateid_cr                    float64
# goalid_cr                        float64
# time_cr                          float64
# adLogType_cr                     float64
# v_cr                             float64
# pricingtype_cr                   float64
# osId_cr                          float64
# browserId_cr                     float64
# cityId_cr                        float64
# stateId_cr                       float64
# modelDimId_cr                    float64
# lookUpFrom_cr                    float64
# ispDimId_cr                      float64
# ...

# %%
new_data_main.describe()
# Out:
#        conversiontime_cr  adslotdimid_cr       algo_cr  clickbid_cr  \
# count       9.650000e+02      965.000000    965.000000   965.000000
# mean        1.620000e+12   287159.814508    135.205181     3.291064
# std         0.000000e+00    82452.398233   1669.993626     2.327387
# min         1.620000e+12   129117.000000      1.000000     0.900000
# 25%         1.620000e+12   233531.000000     18.000000     2.790000
# 50%         1.620000e+12   332775.000000     33.000000     2.790000
# 75%         1.620000e+12   355670.000000     38.000000     2.790000
# max         1.620000e+12   360638.000000  26006.000000    21.942000
#
#          geodimid_cr  itemcolumbiaid_cr     itemid_cr   position_cr  \
# count     965.000000       9.650000e+02  9.650000e+02  9.650000e+02
# mean      475.873575       5.527204e+06  5.020330e+07  2.081476e+07
# std     10224.336657       1.175546e+05  4.804771e+06  6.400076e+07
# min       144.000000       3.238328e+06  2.050601e+07  0.000000e+00
# ...

# %%
new_data_main.cov()
# Out:
#                                conversiontime_cr  adslotdimid_cr  \
# conversiontime_cr                            0.0    0.000000e+00
# adslotdimid_cr                               0.0    6.798398e+09
# algo_cr                                      0.0   -4.859980e+06
# clickbid_cr                                  0.0    1.654219e+04
# geodimid_cr                                  0.0    1.505367e+07
# itemcolumbiaid_cr                            0.0    5.378858e+08
# itemid_cr                                    0.0    3.291632e+10
# position_cr                                  0.0    7.913128e+11
# pubclientid_cr                               0.0    8.547390e+08
# siteId_cr                                    0.0    6.318096e+07
# templateid_cr                                0.0    1.085799e+08
# goalid_cr                                    0.0   -9.628034e+06
# time_cr                                      0.0    0.000000e+00
# ...

# %%
new_data_main.corr()
# Out:
#                                conversiontime_cr  adslotdimid_cr   algo_cr  \
# conversiontime_cr                            NaN             NaN       NaN
# adslotdimid_cr                               NaN        1.000000 -0.035295
# algo_cr                                      NaN       -0.035295  1.000000
# clickbid_cr                                  NaN        0.086203 -0.014321
# geodimid_cr                                  NaN        0.017857 -0.002607
# itemcolumbiaid_cr                            NaN        0.055494 -0.022044
# itemid_cr                                    NaN        0.083087 -0.011084
# position_cr                                  NaN        0.149955 -0.020536
# pubclientid_cr                               NaN        0.327938  0.051611
# siteId_cr                                    NaN        0.542110  0.021395
# templateid_cr                                NaN        0.776619 -0.037119
# ...

# %%
from sklearn.preprocessing import MaxAbsScaler

sc = MaxAbsScaler()

# %%
new_data_main.iloc[:, :-1] = sc.fit_transform(new_data_main.iloc[:, :-1])

# %%
new_data_main
# Out:
#      conversiontime_cr  adslotdimid_cr   algo_cr  clickbid_cr  geodimid_cr  \
# 0                  1.0        0.890921  0.001461     0.130768     0.000453
# 1                  1.0        0.358362  0.001461     0.127153     0.000453
# 2                  1.0        0.891625  0.000808     0.127153     0.000453
# 3                  1.0        0.890921  0.001461     0.127153     0.000453
# 4                  1.0        0.986496  0.000808     0.127153     0.000453
# ..                 ...             ...       ...          ...          ...
# 960                1.0        0.890405  0.000692     0.091149     0.000453
# 961                1.0        0.928238  0.000231     0.127153     0.000453
# 962                1.0        0.965203  0.000038     0.455747     0.000453
# 963                1.0        0.989779  0.000808     0.127153     0.000453
# 964                1.0        0.989779  0.001461     0.127153     0.000453
#
# ...

# %%
new_data_main.corr()
# Out:
#                                conversiontime_cr  adslotdimid_cr   algo_cr  \
# conversiontime_cr                            NaN             NaN       NaN
# adslotdimid_cr                               NaN        1.000000 -0.035295
# algo_cr                                      NaN       -0.035295  1.000000
# clickbid_cr                                  NaN        0.086203 -0.014321
# geodimid_cr                                  NaN        0.017857 -0.002607
# itemcolumbiaid_cr                            NaN        0.055494 -0.022044
# itemid_cr                                    NaN        0.083087 -0.011084
# position_cr                                  NaN        0.149955 -0.020536
# pubclientid_cr                               NaN        0.327938  0.051611
# siteId_cr                                    NaN        0.542110  0.021395
# templateid_cr                                NaN        0.776619 -0.037119
# ...

# %%
new_data_main_ = new_data_main.drop(['goalTypeId_cr', 'time_cr', 'conversiontime_cr'], axis=1)

# %%
# new_data_main_

# %%
from sklearn.utils import shuffle

new_data_main_ = shuffle(new_data_main_)

# %%
X = new_data_main_.iloc[:, :-1].values
y = new_data_main_.iloc[:, -1].values

# %%
Samp1x = X[:300]
Samp1y = y[:300]

# %%
Samp2x = X[300:]
Samp2y = y[300:]

# %%
def labelen(y):
    
    y_ = []
    for i in range(len(y)):
        if y[i] == True:
            y_.append(1)
        else:
            y_.append(0)
        
    return y_

Samp1y = labelen(Samp1y)
Samp2y = labelen(Samp2y)
y = labelen(y)

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE()

# %%
X_smote_1, y_smote_1 = sm.fit_resample(Samp1x, Samp1y)
X_smote_2, y_smote_2 = sm.fit_resample(Samp2x, Samp2y)
X_smote, y_smote = sm.fit_resample(X, y)

# %%
X_smote_1.shape, X_smote_2.shape, len(y_smote_1), len(y_smote_2)
# Out:
# ((516, 30), (1152, 30), 516, 1152)

# %%
type(y_smote_1), type(y_smote_2)
# Out:
# (list, list)

# %%
l = y_smote_1 + y_smote_2

# %%
len(l)
# Out:
# 1668

# %%
d1 = pd.DataFrame(data=X_smote_1)
d2 = pd.DataFrame(data=X_smote_2)

# %%
pd.concat([d1, d2], ignore_index=True)
# Out:
#             0         1         2         3         4         5   \
# 0     0.733170  0.000038  0.127153  0.000453  0.998172  0.986170
# 1     0.360744  0.000038  0.127153  0.000453  0.976539  0.917923
# 2     0.936244  0.001461  0.127153  0.000453  0.977039  0.917430
# 3     0.609600  0.000077  0.127153  0.000453  0.994434  0.975037
# 4     0.928238  0.000077  0.127153  0.000453  0.998518  0.979420
# ...        ...       ...       ...       ...       ...       ...
# 1663  0.358362  0.001441  0.127153  0.000453  0.976539  0.917923
# 1664  0.891156  0.001474  0.141282  0.000453  0.976417  0.917923
# 1665  0.914675  0.001246  0.141282  0.000453  0.976474  0.917923
# 1666  0.647550  0.000754  0.042955  0.000456  0.983279  0.986161
# 1667  0.890921  0.001461  0.132943  0.000453  0.976417  0.917923
#
#                 6         7         8         9   ...        20        21  \
# 0     1.225933e-09  0.159238  0.369842  0.900905  ...  0.979856  0.331797
# ...

# %%
Counter(l)
# Out:
# Counter({0: 834, 1: 834})

# %%
Counter(l)
# Out:
# Counter({0: 834, 1: 834})

# %%
# !pip install xgboost

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier(max_depth=5, learning_rate=0.1, objective='multi:softmax', n_estimators=1000, 
                        num_class=7)

# %%
# xgb.fit(X_smote, y_smote)

# %%
# from sklearn.linear_model import LogisticRegression

# lg = LogisticRegression(C = 100, max_iter=100000)

# %%
# lg.fit(X_smote, y_smote)

# %%
# from sklearn.ensemble import RandomForestClassifier
# rf = RandomForestClassifier()

# %%
# rf.fit(X_smote, y_smote)

# %%
# from sklearn.ensemble import VotingClassifier #voting classifier
# from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier #random forest, Adaboostclassifier
# from sklearn.tree import DecisionTreeClassifier #Decision tree classifier 
from sklearn.svm import SVC #Support vector machine 
# from sklearn.naive_bayes import GaussianNB #Guassian Bias

# estimator = [] #Empty estimator Created
# fr = RandomForestClassifier() #Created Object for the random forest classifier
# estimator.append(('FR', 
#                   RandomForestClassifier())) #appending the randomforest classifier into the empty classifier 
# estimator.append(('SVC', SVC())) #appending support vector classifier into the empty classifier
# estimator.append(('GB', GaussianNB())) #Appending gaussian naive bayes algorithm into the classifier 
# estimator.append(('DTC', DecisionTreeClassifier())) #appending Decision tree classifier into the classifiers
# estimator.append(('AB', AdaBoostClassifier(base_estimator=fr)))# Appending Adaboost classifier into the classifier 


# Voting_classifier = VotingClassifier(estimator) #Creating object for the voting classifier
# Voting_classifier.fit(X_smote, y_smote) #fitting the data into the classifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
gpc = GaussianProcessClassifier()

# %%
# from sklearn.model_selection import GridSearchCV

# params = {
#     'FR__n_estimators' : [500, 1000, 1200, 1500],
#     'SVC__C' : [20, 50, 60, 100, 150],
#     'SVC__max_iter' : [1000, 4000, 5000, 7000, 10000],
#     'DTC__max_depth' : [7, 8, 9, 10, 11, 12]
# }

# from sklearn.model_selection import GridSearchCV

# params = {
    
#     "max_iter_predict" :[1000],
#     "random_state" : [10, 100, 300, 400],
#     "kernel" : [1.0 * RBF(1.0), 2.0 * RBF(1.0), 3.0 * RBF(1.0)]
# }


# grid = GridSearchCV(estimator=gpc, param_grid=params, cv=5)


from sklearn.ensemble import RandomForestClassifier

# svm = RandomForestClassifier()





# from sklearn.model_selection import GridSearchCV

# params = { 
#     'n_estimators': [200, 500, 1000],
#     'max_features': ['auto', 'sqrt', 'log2'],
#     'max_depth' : [4,5,6,7,8],
#     'criterion' :['gini', 'entropy'],
#     'random_state' : [30, 42, 50, 60]
# }

# grid = GridSearchCV(estimator=svm, param_grid=params, cv=10)


# grid = RandomForestClassifier(criterion= 'gini',
#  max_depth= 8,
#  max_features= 'auto',
#  n_estimators= 500,
#  random_state= 30)

# from sklearn.model_selection import cross_val_score
# score = cross_val_score(grid, X_smote, y_smote, cv=10)

# %%
# final_model = xgb.fit(X_smote, y_smote)
# score.mean()

# %%
# grid.fit(X_smote, y_smote)

# %%
# grid.best_params_

# %%
import keras

# %%
from keras.layers import Dense, Dropout #Dense Layer (ANN), Drop out Layer
from keras.optimizers import SGD #Optimizr SGD
from keras.models import Sequential #SequentialA Layer
from keras.utils import to_categorical #To_categorical

# %%
# # Validation data 
from sklearn.model_selection import train_test_split
X_train, X_val, Y_train, Y_val= train_test_split(X_smote, y_smote, test_size=0.2)

# %%
Y_train = to_categorical(Y_train, num_classes=2)
Y_val = to_categorical(Y_val, num_classes=2)

# %%
from keras import regularizers
from keras.layers import Dropout
model = Sequential()
model.add(Dense(1024, input_shape=(X_train.shape[1],)))
model.add(Dense(512, activation='relu'))
model.add(Dense(216, activation='relu'))
model.add(Dense(2, activation="softmax"))

# %%
import keras
from keras.optimizers import SGD
model.compile(loss='categorical_crossentropy',optimizer="sgd" ,metrics=['accuracy',  #Accuracy
                                                       keras.metrics.Precision(), #Precision 
                                                       keras.metrics.Recall()]) #Recall

# %%
history = model.fit(X_train, Y_train, #Train data
         batch_size=48,epochs=200, #batch size and epoc
         steps_per_epoch = len(X_train)//48,
         validation_data = (X_val, Y_val)) #Validation data
# Out:
# Epoch 1/200
# 27/27 [==============================] - 2s 45ms/step - loss: 0.6831 - accuracy: 0.6184 - precision: 0.6184 - recall: 0.6184 - val_loss: 0.6761 - val_accuracy: 0.6347 - val_precision: 0.6347 - val_recall: 0.6347
# Epoch 2/200
# 27/27 [==============================] - 0s 14ms/step - loss: 0.6661 - accuracy: 0.6948 - precision: 0.6948 - recall: 0.6948 - val_loss: 0.6708 - val_accuracy: 0.6317 - val_precision: 0.6317 - val_recall: 0.6317
# Epoch 3/200
# 27/27 [==============================] - 0s 14ms/step - loss: 0.6576 - accuracy: 0.6820 - precision: 0.6820 - recall: 0.6820 - val_loss: 0.6667 - val_accuracy: 0.6317 - val_precision: 0.6317 - val_recall: 0.6317
# Epoch 4/200
# 27/27 [==============================] - 0s 14ms/step - loss: 0.6513 - accuracy: 0.6906 - precision: 0.6906 - recall: 0.6906 - val_loss: 0.6656 - val_accuracy: 0.5778 - val_precision: 0.5778 - val_recall: 0.5778
# Epoch 5/200
# ...

# %%
import matplotlib.pyplot as plt
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'])
plt.show()


# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'])
plt.show()

plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'])
plt.show()

plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'])
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'precision', 'recall', 'val_loss', 'val_accuracy', 'val_precision', 'val_recall'])

# %%
from sklearn.linear_model import LogisticRegression

# %%
lg = LogisticRegression()

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()

# %%
# from sklearn.model_selection import GridSearchCV

# params = {
#     "n_estimators" : [100, 150, 200, 500, 800],
#     "criterion" : ['gini', 'entropy'],
#     "random_state" : [10, 40, 100, 20],
#     "class_weight" : ['balanced', 'balanced_subsample']
# }

# grid = GridSearchCV(estimator=rf, param_grid=params, cv=3)

# %%
# grid.get_params

# %%
# grid.best_params_

# %%
# grid.fit(X_train, Y_train)

# %%
# predd = grid.predict(X_val)
# predd

# %%
# from sklearn.metrics import accuracy_score, classification_report

# print(accuracy_score(Y_val, predd))
# print(classification_report(Y_val, predd))

# %%
# print(accuracy_score(Y_train, grid.predict(X_train)))

# %% [markdown]
# # Test

# %%
test_data = pd.read_csv("./Test Data.csv")

# %%
test_data.shape
# Out:
# (455, 56)

# %%
# test_data.info()

# %%
test_data = test_data.drop(['goalTypeId_cr', 'time_cr', 'conversiontime_cr', 'clientid_cr', 'clmbuserid_cr', 'imprid_cr',
                              'audiences_cr', 'ip_cr', 'refurl_cr', 'connTypeDimId_cr', 'allAudiences_cr'], axis=1)

# %%
id_ = test_data['record_id']
test_data.drop(['record_id'], axis=1, inplace=True)

# %%
test_data
# Out:
#      adslotdimid_cr  algo_cr  clickbid_cr  geodimid_cr  itemcolumbiaid_cr  \
# 0            233531       38          NaN          145            5526656
# 1            356952       20         3.10          144            5488773
# 2            356952       18         3.10          144            5488088
# 3            355768       21          NaN          144            5614054
# 4            355768       21          NaN          144            5614054
# ..              ...      ...          ...          ...                ...
# 450          332783       20         3.10          144            5488773
# 451          129239       20          NaN          144            5488773
# 452          129237       37         3.10          144            5488773
# 453          334760        2          NaN          144            5601460
# 454          239188       38         2.79          144            5488773
#
#      itemid_cr  position_cr  pubclientid_cr  siteId_cr  templateid_cr  ...  \
# ...

# %%
test_data.columns
# Out:
# Index(['adslotdimid_cr', 'algo_cr', 'clickbid_cr', 'geodimid_cr',
#        'itemcolumbiaid_cr', 'itemid_cr', 'position_cr', 'pubclientid_cr',
#        'siteId_cr', 'templateid_cr', 'goalid_cr', 'adLogType_cr', 'v_cr',
#        'pricingtype_cr', 'osId_cr', 'browserId_cr', 'cityId_cr', 'stateId_cr',
#        'modelDimId_cr', 'lookUpFrom_cr', 'ispDimId_cr', 'countryDimId_cr',
#        'conversionDurationInMillis_cr', 'impressionTimeInMillis_cr',
#        'clickTimeInMillis_cr', 'osVerDimId_cr', 'uuidSource_cr',
#        'geoGrpDimId_cr', 'stateGrpDimId_cr', 'deviceId_cr', 'uvh_cr', 'uv_cr',
#        'platformId_cr', 'sdkVersion_cr', 'usrClusterId_cr', 'cityGrpDimId_cr',
#        'siteClusterIds_cr', 'refClusterId_cr', 'paid_cr', 'spend_cr',
#        'attributionType_cr', 'conversionid_cr', 'optimize_on_cr',
#        'bundleId_cr'],
#       dtype='object')

# %%
nullpre = list(test_data.isna().sum()/len(test_data) * 100)

# %%
data_col = list(test_data.columns)
for i in range(len(nullpre)):
    if nullpre[i] > 40.00:
        print(data_col[i])
        test_data.drop([data_col[i]], axis=1, inplace=True)
    else:
        pass
# Out:
# deviceId_cr
# uvh_cr
# uv_cr
# platformId_cr
# sdkVersion_cr
# usrClusterId_cr
# siteClusterIds_cr
# refClusterId_cr
# paid_cr
# spend_cr
# attributionType_cr
# conversionid_cr
# optimize_on_cr
# bundleId_cr

# %%
test_data
# Out:
#      adslotdimid_cr  algo_cr  clickbid_cr  geodimid_cr  itemcolumbiaid_cr  \
# 0            233531       38          NaN          145            5526656
# 1            356952       20         3.10          144            5488773
# 2            356952       18         3.10          144            5488088
# 3            355768       21          NaN          144            5614054
# 4            355768       21          NaN          144            5614054
# ..              ...      ...          ...          ...                ...
# 450          332783       20         3.10          144            5488773
# 451          129239       20          NaN          144            5488773
# 452          129237       37         3.10          144            5488773
# 453          334760        2          NaN          144            5601460
# 454          239188       38         2.79          144            5488773
#
#      itemid_cr  position_cr  pubclientid_cr  siteId_cr  templateid_cr  ...  \
# ...

# %%
cols = test_data.columns

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
imp_mean.fit(test_data)
data = imp_mean.transform(test_data)

# %%
# list(test_data.isna().sum()/len(test_data) * 100)

# %%
new_data_main_.shape
# Out:
# (965, 31)

# %%
bc = list(new_data_main_.columns)
tc = list(test_data.columns)

# %%
id_
# Out:
# 0      1000
# 1      1001
# 2      1002
# 3      1003
# 4      1004
#        ...
# 450    1450
# 451    1451
# 452    1452
# 453    1453
# 454    1454
# Name: record_id, Length: 455, dtype: int64

# %%
X_test = data

# %%
X_test = sc.fit_transform(X_test)

# %%
np.isnan(X_test[0]).sum()
# Out:
# 0

# %%
pred = model.predict(X_test)

# %%
pred
# Out:
# array([[2.5052717e-01, 7.4947280e-01],
#        [5.0669026e-01, 4.9330977e-01],
#        [5.0671154e-01, 4.9328846e-01],
#        [8.0709499e-01, 1.9290498e-01],
#        [8.0709219e-01, 1.9290775e-01],
#        [8.0708736e-01, 1.9291259e-01],
#        [5.1811874e-01, 4.8188126e-01],
#        [2.1133636e-01, 7.8866363e-01],
#        [7.3149490e-01, 2.6850510e-01],
#        [1.7383790e-02, 9.8261619e-01],
#        [8.0674076e-01, 1.9325924e-01],
#        [2.3453027e-01, 7.6546973e-01],
#        [9.9380624e-01, 6.1937650e-03],
#        [6.5829569e-01, 3.4170431e-01],
#        [4.9587128e-01, 5.0412875e-01],
#        [5.4407877e-01, 4.5592123e-01],
#        [7.5490683e-01, 2.4509312e-01],
#        [8.2160288e-01, 1.7839709e-01],
#        [4.2628154e-01, 5.7371849e-01],
#        [5.4407912e-01, 4.5592079e-01],
#        [8.4855539e-01, 1.5144460e-01],
#        [7.4429613e-01, 2.5570387e-01],
#        [7.7684718e-01, 2.2315279e-01],
#        [7.4429619e-01, 2.5570381e-01],
# ...

# %%
fraud = []

for i in range(len(pred)):
    if pred[i] == 1:
        fraud.append(True)
    else:
        fraud.append(False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-96-adfdebdfbdfc> in <module>
#       2
#       3 for i in range(len(pred)):
# ----> 4     if pred[i] == 1:
#       5         fraud.append(True)
#       6     else:
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
data = pd.DataFrame(data={
    "record_id" : id_,
    "conversion_fraud" : fraud
})

# %%
data.to_csv("submission.csv", index=None)
